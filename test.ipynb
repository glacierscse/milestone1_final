# %%
from tsbtreedb import *

# %%
db = connect('test.db')

# %%
db.set(1, '1')
db.set(2, '2')
db.set(3, '3')
db.set(4, '4')

# %%
db.get_smaller_than(4)
# Out:
# [(2, '2'), (1, '1'), (3, '3')]

# %%
db.close()
